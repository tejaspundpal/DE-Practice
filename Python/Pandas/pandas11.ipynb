# %%
import pandas as pd

# %%
df = pd.read_csv('/Workspace/Users/pundpaltejas@gmail.com/DE-Practice/Python/Pandas/cust_details_cleaned.csv')
df

# %%
df = pd.read_csv('/Workspace/Users/pundpaltejas@gmail.com/DE-Practice/Python/Pandas/cust_details_cleaned.csv',names=['id','name','email'])
df

# %%
df = pd.read_csv('/Workspace/Users/pundpaltejas@gmail.com/DE-Practice/Python/Pandas/cust_details_cleaned.csv',header=[1])
df

# %%
df = pd.read_csv('/Workspace/Users/pundpaltejas@gmail.com/DE-Practice/Python/Pandas/cust_details_cleaned.csv',nrows=5)
df

# %%
df = pd.read_csv('/Workspace/Users/pundpaltejas@gmail.com/DE-Practice/Python/Pandas/cust_details_cleaned.csv',skiprows=2)
df

# %%
df = pd.read_csv('/Workspace/Users/pundpaltejas@gmail.com/DE-Practice/Python/Pandas/cust_details_cleaned.csv',skiprows=[2,4])
df

# %%
df = pd.read_csv('/Workspace/Users/pundpaltejas@gmail.com/DE-Practice/Python/Pandas/cust_details_cleaned.csv',usecols=['cust_name'])
df

# %%
df = pd.read_csv('/Workspace/Users/pundpaltejas@gmail.com/DE-Practice/Python/Pandas/cust_details_cleaned.csv',index_col=['cust_id'])
df
